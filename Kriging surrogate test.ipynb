# %%
import numpy as np
import matplotlib.pyplot as plt

from smt.surrogate_models import KRG

xt = np.array([0.0, 1.0, 2.0, 3.0, 4.0])
yt = np.array([0.0, 1.0, 1.5, 0.5, 1.0])

sm = KRG(theta0=[1e-2])
sm.set_training_values(xt, yt)
sm.train()

num = 100
x = np.linspace(0.0, 4.0, num)
y = sm.predict_values(x)

# %%
plt.plot(xt, yt, "o")
plt.plot(x, y)
plt.xlabel("x")
plt.ylabel("y")
plt.legend(["Training data", "Prediction"])
plt.show()

# %%
sm.optimal_par
# Out:
# {'sigma2': array([0.27449344]),
#  'beta': array([[-0.02069621]]),
#  'gamma': array([[-1.42353869],
#         [ 0.38669901],
#         [ 1.28041659],
#         [-0.68743951],
#         [ 0.4438626 ]]),
#  'C': array([[1.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#          0.00000000e+00],
#         [1.05466143e-01, 9.94422894e-01, 0.00000000e+00, 0.00000000e+00,
#          0.00000000e+00],
#         [1.23723515e-04, 1.06044515e-01, 9.94361376e-01, 0.00000000e+00,
#          0.00000000e+00],
#         [1.61442383e-09, 1.24417232e-04, 1.06050930e-01, 9.94360691e-01,
#          0.00000000e+00],
#         [2.34319803e-16, 1.62347811e-09, 1.24424928e-04, 1.06051002e-01,
#          9.94360684e-01]]),
#  'Ft': array([[1.        ],
#         [0.89955075],
#         [0.90961282],
#         [0.90854637],
#         [0.90865878]]),
#  'G': array([[-2.07067726]])}
